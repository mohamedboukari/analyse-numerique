# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from numpy.polynomial import Polynomial

# %%
PO=Polynomial([1,2,0,3])
Q=PO*PO
# P(2)
print (Q.coef[4])
print (Q(2))
# Out:
# 12.0
# 841.0

# %%
def base_lagrange(X,i):
    L=Polynomial([1])
    for j in range(len(X)):
        if i!=j:
            a0=X[j,0]/(X[i,0]-X[j,0])
            a1=1/(X[i,0]-X[j,0])
            L=Polynomial([a0,a1])
    return L

# %%
def polynome_lagrange (X,Y) : 
    P=Polynomial([0]) 
    for i in range (len(X)) :
        P+=Y[i,0]*base_lagrange(X,i)
    return P

# %%
X=np.array([[-1],[2],[1]])
Y=np.array([[2],[1],[-1]])

# %%
P=polynome_lagrange (X,Y)
P
# Out:
# Polynomial([2., 1.], domain=[-1.,  1.], window=[-1.,  1.], symbol='x')

# %%
t =np.linspace(-1,1,100)
plt.plot(X,Y,'ro-',t,P(t))
# Out:
# [<matplotlib.lines.Line2D at 0x22ea7eb8690>,
#  <matplotlib.lines.Line2D at 0x22ea574d9d0>]
